# %%
# import libraries
import datetime
import string
import seaborn as sns
import numpy as np
from numpy import log as ln, array, exp

import gensim
from gensim import corpora, models, similarities,matutils
import random
from scipy.special import softmax
import os

from collections import namedtuple, Counter, defaultdict
import time
import math
from matplotlib import pyplot
import json

# from generative_model import HDHProcess
# from smc import Particle, infer

from keras.callbacks import LambdaCallback, ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, LSTM, Bidirectional, Embedding

# %%
def preprocess(data_dir, save_dir):
    corpus_unprocessed = corpora.MmCorpus(data_dir + '/corpus.mm')
    dictionary = corpora.Dictionary.load(data_dir + '/dictionary.dict')
    views_ind_unprocessed = np.load(data_dir + '/views_ind_1.npy')
    temp_dict = {}
    for i,v in enumerate(views_ind_unprocessed):
        temp_dict[dictionary[i]] = v
    all_docs = []
    len_doc = []
    for i, doc in enumerate(corpus_unprocessed):
        words = doc
        #print words
        new_words = []
        for w in words:
            for j in range(int(w[1])):
                new_words.append(dictionary[w[0]])
        all_docs.append(new_words)
        len_doc.append(len(new_words))
    entities_frequency = list(dictionary.dfs.values())
    hand_picked_stop_words = ['http', 'https', 'www']
    del_ids_stopWords = [dictionary.token2id[e] for i, e in enumerate(hand_picked_stop_words)]
    del_ids_lowFreqs = [i for i, e in enumerate(entities_frequency) if e <= 0]  # or e >= 2000
    del_ids = list(set(del_ids_stopWords) | set(del_ids_lowFreqs))
    #del_ids = list()
    #print('removing terms, length dictionary before filter: ', len(del_ids), len(dictionary))
    #dictionary.filter_tokens(bad_ids=del_ids)
    #print('length dictionary after filter: ', len(dictionary))
    # " check the entities in e.g. people. The view_index for each category: People view 3 , Application view 2, KW view 1, BOW view 0 "
    # people_ind = [i for i in range(len(views_ind_unprocessed)) if views_ind_unprocessed[i] == 3]
    # people = []
    # for i in range(len(people_ind)):
    #     people.append(dictionary[people_ind[i]])
    #views_ind = np.delete(views_ind_unprocessed, del_ids)
    views_ind = np.zeros((len(dictionary),), dtype=int)
    for key in dictionary:
        views_ind[key] = temp_dict[dictionary[key]]
    print('num of terms unprocessed: ', corpus_unprocessed.num_terms)
    corpus_processed = [dictionary.doc2bow(doc) for doc in all_docs]
    #corpus_processed = corpus_unprocessed
    
    dictionary.save(save_dir + 'dictionary_processed.dict')
    corpora.MmCorpus.serialize(save_dir + 'corpus_processed.mm', corpus_processed)
    corpus = corpora.MmCorpus(save_dir + 'corpus_processed.mm')
    print('num of terms processed: ', corpus.num_terms)
    print('views_ind leng: ', len(views_ind))
    #views_ind = views_ind_unprocessed
    vocab_size = corpus.num_terms

    all_docs = []
    len_doc = []
    for i, doc in enumerate(corpus):
        words = doc
        words = [dictionary[w[0]] for w in words]
        all_docs.append(words)
        len_doc.append(len(words))
    return(corpus, dictionary, views_ind, vocab_size)

# %%
# A DataLoader is an object that loads the log data
# A data matrix is a matrix with n rows (num_data) and d columns (num_features)
# the features are themselves grouped in different views (num_views)
class DataLoader:
    def __init__(self, data_dir, save_dir):
        """For initialization"""
        #Parameters

        self.corpus, self.dictionary, self.views_ind, self.vocab_size = preprocess(data_dir, save_dir)

        self.num_features = self.corpus.num_terms          #total number of features # here num_features is num_entities
        self.num_data = self.corpus.num_docs               #total number of data (snapshots)
        self.num_views = max(self.views_ind) + 1           #total number of views views= [0=BOW, 1=KW, 2=App, 3=People]
        self.Data = None                                   #todo: (it may be impossible to create this) a num_data*num_featurs array
        #name of the features
        self.feature_names = [self.dictionary.get(i) for i in range(self.num_features) ]
        self.num_items_per_view = [sum(self.views_ind == i) for i in range(self.num_views)]

    def print_info(self):
        print ('The corpus has %d items' %self.num_data+' and %d features'%self.num_features+\
              ' and %d views' %self.num_views +' there are %d' %self.corpus.num_nnz +' non-zero elements')
        print ('People view %d' % self.num_items_per_view[3]+ ' items, Application view %d' %self.num_items_per_view[2]+\
              ' items, Doc view %d' %self.num_items_per_view[4]+\
              ' items, KW view %d' %self.num_items_per_view[1]+' items, BOW view %d' %self.num_items_per_view[0]+' items.')

    def process_item_info(self):
        #This function is used for offline feedback gathering
        print ('The corpus has %d items' %self.num_data+' and %d features'%self.num_features+\
              ' and %d views' %self.num_views +' there are %d' %self.corpus.num_nnz +' non-zero elements')
        print ('People view %d' %sum(self.views_ind == 3)+ ' items, Application view %d' %sum(self.views_ind == 2)+\
              ' items, Doc view %d' %sum(self.views_ind == 4)+\
              ' items, KW view %d' %sum(self.views_ind == 1)+' items, BOW view %d' %sum(self.views_ind == 0)+' items.')

        def returnReverse(k,v):
            return (v,k)
        #get the document frequency of the terms (i.e. how many document did a particular term occur in):
        term_frequency_dic = self.dictionary.dfs
        sorted_term_ferequency = sorted(term_frequency_dic.items(), key=lambda x : x[1], reverse=True)
        sorted_IDs = [sorted_term_ferequency[i][0] for i in range(self.num_features)]

        count_term = [y for (x,y) in sorted_term_ferequency]
        pyplot.hist(count_term[9000:self.num_features-1], 20, facecolor='green')
        pyplot.xlabel('number of occurrences in the corpus')
        pyplot.ylabel('count')
        pyplot.show()
        num_of_1_occurance = len([y for (x,y) in sorted_term_ferequency if y==1])
        print ('%d terms' %num_of_1_occurance+' have only appeared once in the corpus')
        term_names_1_occurance = [(self.feature_names[x]) for (x,y) in sorted_term_ferequency if y==1 ]
        #with open('term_names_1_occurance.txt', 'w') as outfile:
        #    json.dump(term_names_1_occurance, outfile)
        #those terms can be removed from the dictionary.todo: HOWEVER, they should be removed when the corpus is being made
        #print self.dictionary
        #self.dictionary.filter_extremes(no_below=2)
        #print self.dictionary

        AP_names = [(self.feature_names[sorted_IDs[i]]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 2]
        AP_ids = [(sorted_IDs[i]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 2]
        
        Doc_names = [(self.feature_names[sorted_IDs[i]]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 4]
        Doc_ids = [(sorted_IDs[i]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 4]

        KW_names = [(self.feature_names[sorted_IDs[i]]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 1]
        KW_ids = [(sorted_IDs[i]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 1]

        People_names = [(self.feature_names[sorted_IDs[i]]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 3]
        People_ids = [(sorted_IDs[i]) for i in range(self.num_features) \
                    if  self.views_ind[sorted_IDs[i]] == 3]

        num_to_show = 1000 #
        data = {}
        data["AP_names"] = AP_names[:num_to_show]
        data["Doc_names"] = Doc_names[:num_to_show]
        data["KW_names"] = KW_names[:num_to_show]
        data["People_names"] = People_names[:num_to_show]
        data["AP_ids"] = AP_ids[:num_to_show]
        data["Doc_ids"] = Doc_ids[:num_to_show]
        data["KW_ids"] = KW_ids[:num_to_show]
        data["People_ids"] = People_ids[:num_to_show]

        print(data)

# %%
# Load data
data = DataLoader('data/test', 'tmp/')
data.print_info()
# Out:
# num of terms unprocessed:  67951
# num of terms processed:  67951
# views_ind leng:  67951
# The corpus has 5460 items and 67951 features and 5 views there are 511910 non-zero elements
# People view 62 items, Application view 188 items, Doc view 1034 items, KW view 44450 items, BOW view 16757 items.

# %%
# doc title from file, can ignore later on
import io
_docs = []
_to_print = {}
for d in data.corpus:
    ts = ''
    app = ''
    title = ''
    for w in d:
        if data.views_ind[w[0]] == -1:
            ts = data.dictionary.get(w[0]).split('ts_')[1]
        if data.views_ind[w[0]] == 2:
            app = data.dictionary.get(w[0])
        if data.views_ind[w[0]] == 4:
            title = data.dictionary.get(w[0])
    _docs.append((ts,app,title))
    _to_print[ts]=[title,app]

# %%
# Out:
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 13s 93ms/step - loss: 0.0068 - accuracy: 0.2546 - val_loss: 0.0060 - val_accuracy: 0.3464
# Epoch 5/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.2760INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch005-topics131-sequence10-loss0.0067-acc0.2740-val_loss0.0059-val_acc0.4295/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 12s 86ms/step - loss: 0.0067 - accuracy: 0.2740 - val_loss: 0.0059 - val_accuracy: 0.4295
# Epoch 6/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.2941INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch006-topics131-sequence10-loss0.0066-acc0.2933-val_loss0.0058-val_acc0.4545/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 12s 86ms/step - loss: 0.0066 - accuracy: 0.2933 - val_loss: 0.0058 - val_accuracy: 0.4545
# Epoch 7/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.3141INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch007-topics131-sequence10-loss0.0065-acc0.3141-val_loss0.0057-val_acc0.4625/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 11s 82ms/step - loss: 0.0065 - accuracy: 0.3141 - val_loss: 0.0057 - val_accuracy: 0.4625
# Epoch 8/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.3180WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 33ms/step - loss: 0.0064 - accuracy: 0.3193 - val_loss: 0.0057 - val_accuracy: 0.4554
# Epoch 9/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0064 - accuracy: 0.3341WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0064 - accuracy: 0.3344 - val_loss: 0.0057 - val_accuracy: 0.4616
# Epoch 10/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.3328WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0063 - accuracy: 0.3328 - val_loss: 0.0056 - val_accuracy: 0.4625
# Epoch 11/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.3394WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 27ms/step - loss: 0.0063 - accuracy: 0.3394 - val_loss: 0.0056 - val_accuracy: 0.4625
# Epoch 12/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.3392INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch012-topics131-sequence10-loss0.0063-acc0.3380-val_loss0.0056-val_acc0.4634/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 12s 87ms/step - loss: 0.0063 - accuracy: 0.3380 - val_loss: 0.0056 - val_accuracy: 0.4634
# Epoch 13/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3543INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch013-topics131-sequence10-loss0.0062-acc0.3526-val_loss0.0056-val_acc0.4661/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 19s 142ms/step - loss: 0.0062 - accuracy: 0.3526 - val_loss: 0.0056 - val_accuracy: 0.4661
# Epoch 14/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.3504WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 33ms/step - loss: 0.0063 - accuracy: 0.3499 - val_loss: 0.0056 - val_accuracy: 0.4661
# Epoch 15/100
# 135/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3514WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 28ms/step - loss: 0.0062 - accuracy: 0.3504 - val_loss: 0.0056 - val_accuracy: 0.4589
# Epoch 16/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.3476WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0062 - accuracy: 0.3476 - val_loss: 0.0056 - val_accuracy: 0.4616
# Epoch 17/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3605WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 30ms/step - loss: 0.0062 - accuracy: 0.3609 - val_loss: 0.0056 - val_accuracy: 0.4643
# Epoch 18/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.3561INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch018-topics131-sequence10-loss0.0062-acc0.3561-val_loss0.0056-val_acc0.4670/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 11s 79ms/step - loss: 0.0062 - accuracy: 0.3561 - val_loss: 0.0056 - val_accuracy: 0.4670
# Epoch 19/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.3631WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 34ms/step - loss: 0.0062 - accuracy: 0.3631 - val_loss: 0.0056 - val_accuracy: 0.4616
# Epoch 20/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3523WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0062 - accuracy: 0.3517 - val_loss: 0.0056 - val_accuracy: 0.4670
# Epoch 21/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.3547WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0062 - accuracy: 0.3547 - val_loss: 0.0056 - val_accuracy: 0.4643
# Epoch 22/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3610WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0062 - accuracy: 0.3599 - val_loss: 0.0056 - val_accuracy: 0.4616
# Epoch 23/100
# 135/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3630WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 30ms/step - loss: 0.0062 - accuracy: 0.3629 - val_loss: 0.0056 - val_accuracy: 0.4634
# Epoch 24/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3621WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0062 - accuracy: 0.3615 - val_loss: 0.0056 - val_accuracy: 0.4652
# Epoch 25/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.3716WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 31ms/step - loss: 0.0061 - accuracy: 0.3698 - val_loss: 0.0056 - val_accuracy: 0.4634
# Epoch 26/100
# 135/137 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.3653WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 32ms/step - loss: 0.0062 - accuracy: 0.3645 - val_loss: 0.0056 - val_accuracy: 0.4616
# Epoch 27/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.3604WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 37ms/step - loss: 0.0062 - accuracy: 0.3604 - val_loss: 0.0056 - val_accuracy: 0.4661
# Epoch 28/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.3752WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0061 - accuracy: 0.3743 - val_loss: 0.0056 - val_accuracy: 0.4589
# Epoch 29/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3682INFO:tensorflow:Assets written to: ./checkpoints/LSTM_LDA-epoch029-topics131-sequence10-loss0.0061-acc0.3682-val_loss0.0056-val_acc0.4688/assets
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# ...
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0061 - accuracy: 0.3668 - val_loss: 0.0057 - val_accuracy: 0.4625
# Epoch 42/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3720WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 36ms/step - loss: 0.0061 - accuracy: 0.3720 - val_loss: 0.0056 - val_accuracy: 0.4607
# Epoch 43/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.3725WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 34ms/step - loss: 0.0061 - accuracy: 0.3734 - val_loss: 0.0057 - val_accuracy: 0.4518
# Epoch 44/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3698WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 34ms/step - loss: 0.0061 - accuracy: 0.3698 - val_loss: 0.0056 - val_accuracy: 0.4598
# Epoch 45/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3688WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 34ms/step - loss: 0.0061 - accuracy: 0.3688 - val_loss: 0.0057 - val_accuracy: 0.4563
# Epoch 46/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3739WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 34ms/step - loss: 0.0061 - accuracy: 0.3739 - val_loss: 0.0057 - val_accuracy: 0.4598
# Epoch 47/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.3814WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 4s 33ms/step - loss: 0.0060 - accuracy: 0.3814 - val_loss: 0.0056 - val_accuracy: 0.4643
# Epoch 48/100
# 136/137 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.3752WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0061 - accuracy: 0.3743 - val_loss: 0.0056 - val_accuracy: 0.4625
# Epoch 49/100
# 137/137 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.3750WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# WARNING:tensorflow:Network returning invalid probability values. The last layer might not normalize predictions into probabilities (like softmax or sigmoid would).
# 137/137 [==============================] - 5s 35ms/step - loss: 0.0061 - accuracy: 0.3750 - val_loss: 0.0056 - val_accuracy: 0.4607

# %%
items = {}
_numberOfVisits = 0
for curr_doc in _docs[:cut_index-1]:
    if curr_doc[2] not in items:
        items[curr_doc[2]] = ItemState()
    next_doc = _docs[_docs.index(curr_doc)+1]
    items[curr_doc[2]].addVisitToItem(next_doc[2], 1000, next_doc[0])
    items[curr_doc[2]].updateVisits(_numberOfVisits)
    _numberOfVisits+=1

# %%
# get frency recence
crfWeights = [ItemFactory() for i in range(cut_index-10)]

for i in range(cut_index-10,len(_docs)):
    item_factory = ItemFactory()
    for _doc in _docs[:i]:
        _id = _doc[2]
        _time = '00:10:01'
        item_factory.update(_id, _time)
    crfWeights.append(item_factory)

# %%
print(len(crfWeights))
# Out:
# 5460

# %%
#Check data
#for item,item_state in items.items():
#    print(item,':::', item_state.markovDescription())

# Markov chain
#for curr_doc in _docs[cut_index:cut_index+1]:
#    rec_item = []
#    prev_doc = _docs[_docs.index(curr_doc)-1]
#    print(curr_doc[2])
#    for _item,_state in items[prev_doc[2]].nextVisits.items():
#        xn = items[prev_doc[2]].numberOfVisits
#        x = len(_state)
#        markov = (x + 1) / (xn + 1)
#        rec_item.append((_item, markov))
#    sorted_rec_item = sorted(rec_item, key=takeSecond, reverse=True)
#    for t in sorted_rec_item[:10]:
#        print('\t',str(sorted_rec_item.index(t)+1)+')',t[0][0:50],t[1])

# %%
l = 2.5
d = 0.07
g = 1
#access rank
precision_1_a = []
precision_2_a = []
precision_3_a = []
precision_4_a = []
precision_5_a = []
mrr_a = []
#routine based
precision_1_r = []
precision_2_r = []
precision_3_r = []
precision_4_r = []
precision_5_r = []
mrr_r = []
#markov
precision_1_m = []
precision_2_m = []
precision_3_m = []
precision_4_m = []
precision_5_m = []
mrr_m = []
#frequency recency
precision_1_f = []
precision_2_f = []
precision_3_f = []
precision_4_f = []
precision_5_f = []
mrr_f = []

items = {}
_numberOfVisits = 0
for curr_doc in _docs[:cut_index-1]:
    if curr_doc[2] not in items:
        items[curr_doc[2]] = ItemState()
    next_doc = _docs[_docs.index(curr_doc)+1]
    items[curr_doc[2]].addVisitToItem(next_doc[2], 1000, next_doc[0])
    items[curr_doc[2]].updateVisits(_numberOfVisits)
    _numberOfVisits+=1

    
#all ids
all_ids = defaultdict(int)
all_apps = defaultdict(int)
print(cut_index)
for _doc in _docs[:cut_index]:
    all_ids[_doc[2]] +=1
    
pred_i = 0
for curr_doc in _docs[cut_index:cut_index+n_tests-1]:
    if curr_doc[2] in items:
        print(curr_doc[2],'num visits',items[curr_doc[2]].numberOfVisits,pred_i)
    else:
        print(curr_doc[2],'num visits','0',pred_i)
    #markov
    prev_doc = _docs[_docs.index(curr_doc)-1]
    markovs = {}
    if prev_doc[2] in items:
        for _item,_state in items[prev_doc[2]].nextVisits.items():
            xn = items[prev_doc[2]].numberOfVisits
            x = len(_state)
            markov = (x + 1) / (xn + 1)
            markovs[_item] = markov
    
    #updating markov
    if curr_doc[2] not in items:
        items[curr_doc[2]] = ItemState()
    items[prev_doc[2]].addVisitToItem(curr_doc[2], 1000, curr_doc[0])
    items[prev_doc[2]].updateVisits(_numberOfVisits)
    _numberOfVisits+=1
    
    #markov
    rec_kw = []
    for _id,v in markovs.items():
        markov = markovs[_id]
        rec_kw.append((_id,markov))
    sorted_terms_bl = sorted(rec_kw, key=takeSecond, reverse=True)
    
    recommended_docs_m = []
    for t in sorted_terms_bl:
        #print('\t',str(sorted_terms_bl.index(t)+1)+')',t[0][0:50],t[1])
        recommended_docs_m.append(t[0][:12])
        
    #frequency recency
    rec_kw = []
    for _id,v in markovs.items():
        crf = crfWeights[cut_index+pred_i].items[_id].crfWeight
        rec_kw.append((_id,crf))
    sorted_terms_bl = sorted(rec_kw, key=takeSecond, reverse=True)
    
    recommended_docs_f = []
    for t in sorted_terms_bl:
        #print('\t',str(sorted_terms_bl.index(t)+1)+')',t[0][0:50],t[1])
        recommended_docs_f.append(t[0][:12])
    
    #access rank
    rec_kw = []
    for _id,v in all_ids.items():
        markov = markovs[_id] if _id in markovs else 1e-4
        crf = crfWeights[cut_index+pred_i].items[_id].crfWeight
        rec_kw.append((_id,pow(markov,l)*pow(crf,1/l)))
    sorted_terms_bl = sorted(rec_kw, key=takeSecond, reverse=True)
    
    recommended_docs_a = []
    for t in sorted_terms_bl:
        #print('\t',str(sorted_terms_bl.index(t)+1)+')',t[0][0:50],t[1])
        recommended_docs_a.append(t[0][:12])
        
    #routine
    rec_kw = []
    pattern_entities = {}
    _tmp_patterns = []
    for i in _pred_patterns[pred_i]:
        pattern_words = particle.per_topic_word_counts[i[0]]
        tmp_words = []
        normalized_score = []
        for word in pattern_words:
            if 'title_' not in word:
                continue
            _tmp_patterns.append((word,(ln(pattern_words[word] + particle.theta_0[0]))*i[1]))
    flat_tmp_patterns = flatRecom(_tmp_patterns)
    pattern_entities = {flat_tmp_patterns[i][0]: flat_tmp_patterns[i][1] for i in range(len(flat_tmp_patterns))}
      
    for _id,v in all_ids.items():
        markov = markovs[_id] if _id in markovs else 1e-4
        routine = pattern_entities[_id] if _id in pattern_entities else 1e-20
        crf = crfWeights[cut_index+pred_i].items[_id].crfWeight
#        rec_kw.append((_id,pow(markov,l)*pow(routine,g)*pow(crf,1/d)))
        rec_kw.append((_id,pow(routine,g)))
    
    sorted_terms_bl = sorted(rec_kw, key=takeSecond, reverse=True)
    
    recommended_docs_r = []
    for t in sorted_terms_bl:
        #print('\t',str(sorted_terms_bl.index(t)+1)+')',t[0][0:50],t[1])
        recommended_docs_r.append(t[0][:12])
    
    pred_i +=1
    
    # Evaluation
    future_doc = curr_doc[2][:12]
    all_apps[curr_doc[1]] +=1
    
    if future_doc not in [k[:12] for k in all_ids.keys()]:
        continue
    #if _hit[pred_i-1] == 0:
    #    continue
    
    # markov
    correct_doc = []
    if future_doc in recommended_docs_m[:1]:
        correct_doc.append(future_doc)
    precision_1_m.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_m[:2]:
        correct_doc.append(future_doc)
    precision_2_m.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_m[:3]:
        correct_doc.append(future_doc)
    precision_3_m.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_m[:4]:
        correct_doc.append(future_doc)
    precision_4_m.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_m[:5]:
        correct_doc.append(future_doc)
    precision_5_m.append(len(correct_doc))
    
    if future_doc in recommended_docs_m:
        mrr_m.append(1/(recommended_docs_m.index(future_doc)+1))
    else:
        mrr_m.append(0)
        
    # frequency recency
    correct_doc = []
    if future_doc in recommended_docs_f[:1]:
        correct_doc.append(future_doc)
    precision_1_f.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_f[:2]:
        correct_doc.append(future_doc)
    precision_2_f.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_f[:3]:
        correct_doc.append(future_doc)
    precision_3_f.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_f[:4]:
        correct_doc.append(future_doc)
    precision_4_f.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_f[:5]:
        correct_doc.append(future_doc)
    precision_5_f.append(len(correct_doc))
    
    if future_doc in recommended_docs_f:
        mrr_f.append(1/(recommended_docs_f.index(future_doc)+1))
    else:
        mrr_f.append(0)
    
    # access rank
    correct_doc = []
    if future_doc in recommended_docs_a[:1]:
        correct_doc.append(future_doc)
    precision_1_a.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_a[:2]:
        correct_doc.append(future_doc)
    precision_2_a.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_a[:3]:
        correct_doc.append(future_doc)
    precision_3_a.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_a[:4]:
        correct_doc.append(future_doc)
    precision_4_a.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_a[:5]:
        correct_doc.append(future_doc)
    precision_5_a.append(len(correct_doc))
    
    if future_doc in recommended_docs_a:
        mrr_a.append(1/(recommended_docs_a.index(future_doc)+1))
    else:
        mrr_a.append(0)
    
    
    correct_doc = []
    if future_doc in recommended_docs_r[:1]:
        correct_doc.append(future_doc)
    precision_1_r.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_r[:2]:
        correct_doc.append(future_doc)
    precision_2_r.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_r[:3]:
        correct_doc.append(future_doc)
    precision_3_r.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_r[:4]:
        correct_doc.append(future_doc)
    precision_4_r.append(len(correct_doc))
    correct_doc = []
    if future_doc in recommended_docs_r[:5]:
        correct_doc.append(future_doc)
    precision_5_r.append(len(correct_doc))
    
    if future_doc in recommended_docs_r:
        mrr_r.append(1/(recommended_docs_r.index(future_doc)+1))
    else:
        mrr_r.append(0)


print('**Makov')
print('Hitrate@1: ', np.mean(precision_1_m))
print('Hitrate@2: ', np.mean(precision_2_m))
print('Hitrate@3: ', np.mean(precision_3_m))
print('Hitrate@4: ', np.mean(precision_4_m))
print('Hitrate@5: ', np.mean(precision_5_m))
print('MRR: ', np.mean(mrr_m))

print('**Frequency recency')
print('Hitrate@1: ', np.mean(precision_1_f))
print('Hitrate@2: ', np.mean(precision_2_f))
print('Hitrate@3: ', np.mean(precision_3_f))
print('Hitrate@4: ', np.mean(precision_4_f))
print('Hitrate@5: ', np.mean(precision_5_f))
print('MRR: ', np.mean(mrr_f))

print('**Access rank')
print('Hitrate@1: ', np.mean(precision_1_a))
print('Hitrate@2: ', np.mean(precision_2_a))
print('Hitrate@3: ', np.mean(precision_3_a))
print('Hitrate@4: ', np.mean(precision_4_a))
print('Hitrate@5: ', np.mean(precision_5_a))
print('MRR: ', np.mean(mrr_a))

print('**Routine')
print('Hitrate@1: ', np.mean(precision_1_r))
print('Hitrate@2: ', np.mean(precision_2_r))
print('Hitrate@3: ', np.mean(precision_3_r))
print('Hitrate@4: ', np.mean(precision_4_r))
print('Hitrate@5: ', np.mean(precision_5_r))
print('MRR: ', np.mean(mrr_r))
# Out:
# 4352
# title_elements.css num visits 24 0
# title_medisyn_|_prototype num visits 246 1
# title_userauthen.js num visits 43 2
# title_medisyn_|_prototype num visits 247 3
# title_chenhe_—_chenhe@shell:_~_—_-bash_—_80×36 num visits 0 4
# title_ver4mongodb_—_mongod_◂_sudo_—_80×24 num visits 9 5
# title_ver7anno_—_-bash_—_80×24 num visits 2 6
# title_userauthen.js_routes num visits 6 7
# title_ver7anno_—_-bash_—_80×24 num visits 3 8
# title_userauthen.js_routes num visits 7 9
# title_ver7anno_—_node_bin/www_—_80×24 num visits 29 10
# title_medisyn_|_prototype num visits 248 11
# title_userauthen.js num visits 44 12
# title_medisyn_|_prototype num visits 249 13
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 89 14
# title_medisyn_|_prototype num visits 250 15
# title_elements.css num visits 25 16
# title_userauthen.js num visits 45 17
# title_medisyn_|_prototype num visits 251 18
# title_userauthen.js num visits 46 19
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 90 20
# title_medisyn_|_prototype num visits 252 21
# title_elements.css num visits 26 22
# title_medisyn_|_prototype num visits 253 23
# title_tryit_editor_v3.5 num visits 6 24
# title_elements.css num visits 27 25
# title_tryit_editor_v3.5 num visits 7 26
# title_medisyn_|_prototype num visits 254 27
# title_elements.css num visits 28 28
# title_userauthen.js num visits 47 29
# title_medisyn_|_prototype num visits 255 30
# title_javascript_-_set_textbox_to_readonly_and_background_color_to_grey_in_jquery_-_stack_overflow num visits 0 31
# title_elements.css num visits 29 32
# title_userauthen.js_routes num visits 8 33
# title_userauthen.js num visits 48 34
# title_elements.css num visits 30 35
# title_javascript_-_set_textbox_to_readonly_and_background_color_to_grey_in_jquery_-_stack_overflow num visits 1 36
# title_medisyn_|_prototype num visits 256 37
# title_elements.css num visits 31 38
# title_medisyn_|_prototype num visits 257 39
# title_elements.css num visits 32 40
# title_svgbody.js num visits 19 41
# title_ver7anno_—_node_bin/www_—_80×24 num visits 30 42
# title_chenhe_—_chenhe@shell:_~_—_-bash_—_80×36 num visits 1 43
# title_chenhe_—_chenhe@shell:_~_—_mongo_—_80×36 num visits 0 44
# title_jquery_textarea_readonly_grey_-_google_search num visits 0 45
# title_jquery_textarea_set_foxus_-_google_search num visits 0 46
# title_jquery_textarea_focus_-_stack_overflow num visits 0 47
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 91 48
# title_userauthen.js num visits 49 49
# title_d3_textarea_set_focus_-_google_search num visits 0 50
# title_userauthen.js num visits 50 51
# title_how_to_make_a_text_field_automatically_active_(set_focus) num visits 0 52
# title_https://d4health.hiit.fi/retrieveallhis num visits 61 53
# title_medisyn_|_prototype num visits 258 54
# title_userauthen.js num visits 51 55
# title_medisyn_|_prototype num visits 259 56
# title_new_tab num visits 48 57
# title_jquery_textarea_remove_foxus_-_google_search num visits 0 58
# title_javascript_-_how_to_remove_focus_from_textarea_when_it_is_in_active_use_-_stack_overflow num visits 0 59
# title_edit_fiddle_-_jsfiddle num visits 0 60
# title_medisyn_|_prototype num visits 260 61
# title_edit_fiddle_-_jsfiddle num visits 1 62
# title_jquery_textarea_remove_foxus_-_google_search num visits 1 63
# title_medisyn_|_prototype num visits 261 64
# title_userauthen.js num visits 52 65
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 92 66
# title_medisyn_|_prototype num visits 262 67
# title_jquery_textarea_set_foxus_-_google_search num visits 1 68
# title_jquery_.focus()_on_textarea_not_working_-_stack_overflow num visits 0 69
# title_userauthen.js num visits 53 70
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 93 71
# title_untitled num visits 21 72
# title_.focus()_|_jquery_api_documentation num visits 0 73
# title_jquery_focus_examples_-_set_focus_on_textbox,_textarea,_select,_checkbox,_radiobutton num visits 0 74
# title_medisyn_|_prototype num visits 263 75
# title_userauthen.js num visits 54 76
# title_medisyn_|_prototype num visits 264 77
# title_userauthen.js num visits 55 78
# title_.focus()_|_jquery_api_documentation num visits 1 79
# title_medisyn_|_prototype num visits 265 80
# title_userauthen.js num visits 56 81
# title_medisyn_|_prototype num visits 266 82
# title_chenhe_—_chenhe@shell:_~_—_mongo_—_80×36 num visits 1 83
# title_medisyn_|_prototype num visits 267 84
# title_svgbody.js num visits 20 85
# title_medisyn_|_prototype num visits 268 86
# title_userauthen.js num visits 57 87
# title_elements.css num visits 33 88
# title_medisyn_|_prototype num visits 269 89
# title_untitled num visits 22 90
# title_medisyn_|_prototype num visits 270 91
# title_inbox_view num visits 37 92
# title_join_the_ux_analytics_tool_demo_view num visits 2 93
# title_data_science_teachers'_day_view num visits 2 94
# title_medisyn_|_prototype num visits 271 95
# title_luana.micallef_chat num visits 52 96
# title_medisyn_|_prototype num visits 272 97
# title_jquery_textarea_set_foxus_-_google_search num visits 2 98
# title_data_science_teachers'_day_view num visits 3 99
# title_documents_—_local num visits 21 100
# title_google_drive num visits 19 101
# title_idv_course_2018 num visits 25 102
# title_luana.micallef_chat num visits 53 103
# title_idv_luana.rtf num visits 0 104
# title_downloads num visits 23 105
# title_documents_—_local num visits 22 106
# title_google_drive num visits 20 107
# title_untitled num visits 23 108
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 94 109
# title_idv_course_2018 num visits 26 110
# title_idv_course_2018_-_google_docs num visits 19 111
# title_idv_luana.rtf num visits 1 112
# title_idv_course_2018_-_google_docs num visits 20 113
# title_idv_course_2018 num visits 27 114
# title_idv_course_2018_-_google_docs num visits 21 115
# title_idv_course_2018 num visits 28 116
# title_principles_-_google_slides num visits 87 117
# title_idv_course_2018 num visits 29 118
# title_idv_course_2018_-_google_docs num visits 22 119
# title_luana.micallef_chat num visits 54 120
# title_idv_course_2018_-_google_docs num visits 23 121
# title_data_science_teachers'_day_view num visits 4 122
# title_raw num visits 2 123
# title_new_tab num visits 49 124
# title_presemo_-_google_search num visits 0 125
# title_presemo num visits 0 126
# title_university_of_helsinki_university_of_helsinki num visits 0 127
# title_presemo num visits 1 128
# title_presemo_-_google_search num visits 1 129
# title_presemo_support_site_-_presemo_-_university_of_helsinki_confluence num visits 0 130
# title_privacy_error num visits 0 131
# title_screen.io num visits 0 132
# title_luana.micallef_chat num visits 55 133
# title_presemo num visits 2 134
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 95 135
# title_idv_course_2018_-_google_docs num visits 24 136
# title_dropbox num visits 4 137
# title_visualizing_and_interacting_with_data num visits 2 138
# title_infovis num visits 1 139
# title_slides num visits 4 140
# title_t-61_5010_lecture4_human_perception_part1.pdf num visits 1 141
# title_t-61_5010_lecture6_human_perception_part3.pdf num visits 0 142
# title_idv_course_2018_-_google_docs num visits 25 143
# title_slides num visits 5 144
# title_idv_course_2018 num visits 30 145
# title_untitled num visits 24 146
# title_human_perception_-_google_slides num visits 18 147
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 96 148
# title_idv_course_2018_-_google_docs num visits 26 149
# title_idv_course_2018 num visits 31 150
# title_infovis_frameworks_-_google_slides num visits 5 151
# title_idv_course_2018_-_google_docs num visits 27 152
# title_infovis_frameworks_-_google_slides num visits 6 153
# title_idv_course_2018_-_google_docs num visits 28 154
# title_inbox_view num visits 38 155
# title_idv_course_2018_-_google_docs num visits 29 156
# title_luana.micallef_chat num visits 56 157
# title_downloads num visits 24 158
# title_2.pdf num visits 0 159
# title_infovis_frameworks_-_google_slides num visits 7 160
# title_2.pdf num visits 1 161
# title_infovis_frameworks_-_google_slides num visits 8 162
# title_2.pdf num visits 2 163
# title_infovis_frameworks_-_google_slides num visits 9 164
# title_2.pdf num visits 3 165
# title_html5でオフラインwebアプリケーションを作ろう num visits 0 166
# title_https://www.slideshare.net num visits 0 167
# title_share_and_discover_knowledge_on_linkedin_slideshare num visits 0 168
# title_munzner_-_google_search num visits 0 169
# title_tamara_munzner:_talks num visits 0 170
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 0 171
# title_data_science_teachers'_day_view num visits 5 172
# title_2.pdf num visits 4 173
# title_new_tab num visits 50 174
# title_publications_|_centre_for_visual_analytics_science_and_technology num visits 0 175
# title_welcome_to_the_cvast_homepage!_|_centre_for_visual_analytics_science_and_technology num visits 0 176
# title_luana.micallef_chat num visits 57 177
# title_downloads num visits 25 178
# title_welcome_to_the_cvast_homepage!_|_centre_for_visual_analytics_science_and_technology num visits 1 179
# title_tacit_knowledge_-_google_search num visits 0 180
# title_tacit_knowledge_-_wikipedia num visits 0 181
# title_downloads num visits 26 182
# title_google_drive num visits 21 183
# title_myprez num visits 6 184
# title_visual_analytics num visits 0 185
# title_a_case_study_using_visuali... num visits 35 186
# title_2.pdf num visits 5 187
# title_visual_analytics num visits 1 188
# title_idv_course_2018_-_google_docs num visits 30 189
# title_weboodi num visits 11 190
# title_idv_course_2018_-_google_docs num visits 31 191
# title_idv_course_2018 num visits 32 192
# title_https://docs.google.com/presentation/u/0/d/1o2xt1vsqnmpgtpxaudv_fqr3cmv_finvql-lix6oie8/edit?usp=drive_web num visits 0 193
# title_idv_course_2018 num visits 33 194
# title_welcome_to_the_cvast_homepage!_|_centre_for_visual_analytics_science_and_technology num visits 2 195
# title_idv_course_2018_-_google_docs num visits 32 196
# title_interactive_data_visualization_-_opetussuunnitelma_-_university_of_helsinki_confluence num visits 4 197
# title_idv_course_2018_-_google_docs num visits 33 198
# title_raw num visits 3 199
# title_data_science_teachers'_day_view num visits 6 200
# title_raw num visits 4 201
# title_edit_fiddle_-_jsfiddle num visits 2 202
# title_idv_course_2018_-_google_docs num visits 34 203
# title_luana.micallef_chat num visits 58 204
# title_web.pdf num visits 0 205
# title_idv_course_2018_-_google_docs num visits 35 206
# title_web.pdf num visits 1 207
# title_weboodi num visits 12 208
# title_free_data_visualization_software_|_tableau_public num visits 0 209
# title_chen_—_profile_|_tableau_public num visits 0 210
# title_book2_-_chen_|_tableau_public num visits 0 211
# title_all_notes num visits 98 212
# title_book2_-_chen_|_tableau_public num visits 1 213
# title_idv_course_2018_-_google_docs num visits 36 214
# title_luana.micallef_chat num visits 59 215
# title_deducer:_a_gui_for_r_-_windows_installation num visits 0 216
# title_luana.micallef_chat num visits 60 217
# title_matplotlib_in_python_-_google_search num visits 0 218
# title_matplotlib:_python_plotting_—_matplotlib_2.1.2_documentation num visits 0 219
# title_new_tab num visits 51 220
# title_idv_course_2018_-_google_docs num visits 37 221
# title_calendar num visits 11 222
# title_idv_course_2018_-_google_docs num visits 38 223
# title_calendar num visits 12 224
# title_all_notes num visits 99 225
# title_presemo_support_site_-_presemo_-_university_of_helsinki_confluence num visits 1 226
# title_idv_course_2018_-_google_docs num visits 39 227
# title_calendar num visits 13 228
# title_idv_course_2018_-_google_docs num visits 40 229
# title_data_science_teachers'_day_view num visits 7 230
# title_idv_course_2018_-_google_docs num visits 41 231
# title_calendar num visits 14 232
# title_idv_course_2018_-_google_docs num visits 42 233
# title_calendar num visits 15 234
# title_idv_course_2018_-_google_docs num visits 43 235
# title_web.pdf num visits 2 236
# title_aalto_university_code_of_academic_integrity_and_handling_violations_thereof_-_academic_rules_and_regulations_-_into num visits 0 237
# title_web.pdf num visits 3 238
# title_aalto_university_code_of_academic_integrity_and_handling_violations_thereof_-_academic_rules_and_regulations_-_into num visits 1 239
# title_calendar num visits 16 240
# title_e-lomake_-_pizza_evening_of_docs_students_2.3.2018 num visits 0 241
# title_pizza_evening_of_docs_students_view num visits 2 242
# title_calendar num visits 17 243
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 97 244
# title_home_chat num visits 16 245
# title_e-lomake_-_pizza_evening_of_docs_students_2.3.2018 num visits 1 246
# title_aalto_university_code_of_academic_integrity_and_handling_violations_thereof_-_academic_rules_and_regulations_-_into num visits 2 247
# title_inbox_(connection_logging_enabled) num visits 2 248
# title_2.pdf num visits 6 249
# title_data_science_teachers'_day_view num visits 8 250
# title_luana.micallef_chat num visits 61 251
# title_questionnaire_-_google_search num visits 0 252
# title_google_forms num visits 18 253
# title_medisyn_questionnaire_-_google_forms num visits 56 254
# title_luana.micallef_chat num visits 62 255
# title_medisyn_questionnaire_-_google_forms num visits 57 256
# title_medisyn_|_prototype num visits 273 257
# title_medisyn_questionnaire_-_google_forms num visits 58 258
# title_medisyn_|_prototype num visits 274 259
# title_medisyn_questionnaire_-_google_forms num visits 59 260
# title_medisyn_|_prototype num visits 275 261
# title_all_notes num visits 100 262
# title_visual_analytics num visits 2 263
# title_data_science_teachers'_day_view num visits 9 264
# title_history_evaluation num visits 56 265
# title_data_science_teachers'_day_view num visits 10 266
# title_insight_provenance_for_vast_view num visits 8 267
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 69 268
# title_insight_provenance_for_vast_view num visits 9 269
# title_2.pdf num visits 7 270
# title_all_notes num visits 101 271
# title_email_participants_-_google_docs num visits 43 272
# title_medisyn_|_history num visits 164 273
# title_medisyn_|_prototype num visits 276 274
# title_all_notes num visits 102 275
# title_medisyn_|_prototype num visits 277 276
# title_idv_course_2018_-_google_docs num visits 44 277
# title_email_participants_-_google_docs num visits 44 278
# title_medisyn_|_prototype num visits 278 279
# title_email_participants_-_google_docs num visits 45 280
# title_all_notes num visits 103 281
# title_email_participants_-_google_docs num visits 46 282
# title_new_tab num visits 52 283
# title_presemo_support_site_-_presemo_-_university_of_helsinki_confluence num visits 2 284
# title_email_participants_-_google_docs num visits 47 285
# title_history_evaluation num visits 57 286
# title_email_participants_-_google_docs num visits 48 287
# title_insight_provenance_for_vast_view num visits 10 288
# title_pizza_evening_of_docs_students_view num visits 3 289
# title_insight_evaluation_plan.pdf num visits 1 290
# title_email_participants_-_google_docs num visits 49 291
# title_all_notes num visits 104 292
# title_pizza_evening_of_docs_students_view num visits 4 293
# title_email_participants_-_google_docs num visits 50 294
# title_pizza_evening_of_docs_students_view num visits 5 295
# title_google_docs_-_create_and_edit_documents_online,_for_free. num visits 3 296
# title_google_docs num visits 10 297
# title_email_participants_-_google_docs num visits 51 298
# title_google_docs num visits 11 299
# title_idv_course_2018_-_google_docs num visits 45 300
# title_home_chat num visits 17 301
# title_tung_vuong_chat num visits 20 302
# title_pizza_evening_of_docs_students_view num visits 6 303
# title_idv_course_2018_-_google_docs num visits 46 304
# title_calendar num visits 18 305
# title_tung_vuong_chat num visits 21 306
# title_calendar num visits 19 307
# title_idv_course_2018_-_google_docs num visits 47 308
# title_pizza_evening_of_docs_students_view num visits 7 309
# title_new_message_compose num visits 13 310
# title_tung_vuong_chat num visits 22 311
# title_idv_course_2018_-_google_docs num visits 48 312
# title_new_message_compose num visits 14 313
# title_idv_course_2018_-_google_docs num visits 49 314
# title_new_message_compose num visits 15 315
# title_idv_course_2018_-_google_docs num visits 50 316
# title_new_message_compose num visits 16 317
# title_idv_course_2018_-_google_docs num visits 51 318
# title_all_notes num visits 105 319
# title_tung_vuong_chat num visits 23 320
# title_google_docs_-_google_search num visits 4 321
# title_idv_course_2018_-_google_docs num visits 52 322
# title_new_message_compose num visits 17 323
# title_insight_evaluation_plan.pdf num visits 2 324
# title_2.pdf num visits 8 325
# title_new_message_compose num visits 18 326
# title_pizza_evening_of_docs_students_view num visits 8 327
# title_ella_peltonen_defends_her_phd_thesis_view num visits 0 328
# title_oswald_barral_defends_his_phd_thesis_view num visits 0 329
# title_https://helda.helsinki.fi/handle/10138/231561 num visits 0 330
# title_implicit_interaction_with_textual_information_using_physiological_signals num visits 0 331
# title_idv_course_2018_-_google_docs num visits 53 332
# title_oswald_barral_defends_his_phd_thesis_view num visits 1 333
# title_new_message_compose num visits 19 334
# title_idv_course_2018_-_google_docs num visits 54 335
# title_new_message_compose num visits 20 336
# title_oswald_barral_defends_his_phd_thesis_view num visits 2 337
# title_new_message_compose num visits 21 338
# title_idv_course_structure_compose num visits 0 339
# title_google_docs_-_google_search num visits 5 340
# title_idv_course_2018_-_google_docs num visits 55 341
# title_oswald_barral_defends_his_phd_thesis_view num visits 3 342
# title_idv_course_structure_view num visits 0 343
# title_idv_course_2018_-_google_docs num visits 56 344
# title_idv_course_structure_view num visits 1 345
# title_idv_course_2018_-_google_docs num visits 57 346
# title_google_docs_-_google_search num visits 6 347
# title_oswald_barral_defends_his_phd_thesis_view num visits 4 348
# title_google_docs_-_google_search num visits 7 349
# title_oswald_barral_defends_his_phd_thesis_view num visits 5 350
# title_google_docs_-_google_search num visits 8 351
# title_google_docs num visits 12 352
# title_idv_course_2018_-_google_docs num visits 58 353
# title_google_docs num visits 13 354
# title_email_participants_-_google_docs num visits 52 355
# title_oswald_barral_defends_his_phd_thesis_view num visits 6 356
# title_data_science_teachers'_day_view num visits 11 357
# title_insight_provenance_for_vast_view num visits 11 358
# title_new_message_compose num visits 22 359
# title_insight_provenance_for_vast_compose num visits 17 360
# title_history_evaluation num visits 58 361
# title_all_notes num visits 106 362
# title_history_evaluation num visits 59 363
# title_insight_provenance_for_vast_compose num visits 18 364
# title_new_tab num visits 53 365
# title_email_participants_-_google_docs num visits 53 366
# title_insight_provenance_for_vast_compose num visits 19 367
# title_insight_provenance_for_vast_view num visits 12 368
# title_insight_provenance_for_vast_compose num visits 20 369
# title_idv_course_2018 num visits 34 370
# title_history_evaluation num visits 60 371
# title_save num visits 2 372
# title_history_evaluation num visits 61 373
# title_history_evaluation.pdf num visits 8 374
# title_history_evaluation num visits 62 375
# title_save num visits 3 376
# title_2.pdf num visits 9 377
# title_history_evaluation.pdf num visits 9 378
# title_2.pdf num visits 10 379
# title_insight_provenance_for_vast_compose num visits 21 380
# title_downloads_view num visits 0 381
# title_insight_provenance_for_vast_compose num visits 22 382
# title_history_evaluation.pdf num visits 10 383
# title_insight_provenance_for_vast_compose num visits 23 384
# title_insight_provenance_for_vast_view num visits 13 385
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 1 386
# title_tung_vuong_chat num visits 24 387
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 2 388
# title_tung_vuong_chat num visits 25 389
# title_luana.micallef_chat num visits 63 390
# title_my_library num visits 27 391
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 98 392
# title_my_library num visits 28 393
# title_mendeley_desktop num visits 32 394
# title_my_library num visits 29 395
# title_mendeley_desktop num visits 33 396
# title_my_library num visits 30 397
# title_mendeley_desktop num visits 34 398
# title_cancer_discovery-2013-pemovska-1416-29-1.pdf num visits 0 399
# title_mendeley_desktop num visits 35 400
# title_cancer_discovery-2013-pemovska-1416-29-1.pdf num visits 1 401
# title_luana.micallef_chat num visits 64 402
# title_https://hal.inria.fr/hal-01584729/document num visits 1 403
# title_conceptual_and_methodological_issues_in_evaluating_multidimensional_visualizations_for_decision_support num visits 4 404
# title_downloads num visits 27 405
# title_luana.micallef_chat num visits 65 406
# title_juliana_freire,_ph.d._|_nyu_tandon_school_of_engineering num visits 2 407
# title_luana.micallef_chat num visits 66 408
# title_a_design_space_of_visualization_tasks num visits 0 409
# title_luana.micallef_chat num visits 67 410
# title_publications_|_centre_for_visual_analytics_science_and_technology num visits 1 411
# title_luana.micallef_chat num visits 68 412
# title_silvia_miksch num visits 0 413
# title_publications_|_centre_for_visual_analytics_science_and_technology num visits 2 414
# title_luana.micallef_chat num visits 69 415
# title_tamara_munzner:_talks num visits 1 416
# title_luana.micallef_chat num visits 70 417
# title_sacha_et_al_knowledge_insight_hypothesis_-_google_search num visits 0 418
# title_sacha_et_al_knowledge_insight_hypothesis_2014_-_google_search num visits 0 419
# title_sacha_knowledge_insight_hypothesis_2014_-_google_search num visits 0 420
# title_google_scholar num visits 4 421
# title_luana.micallef_chat num visits 71 422
# title_sacha_knowledge_insight_hypothesis_2014_visualization..._-_google_scholar num visits 0 423
# title_ieee_xplore_full-text_pdf: num visits 12 424
# title_sacha_knowledge_insight_hypothesis_2014_visualization..._-_google_scholar num visits 1 425
# title_mendeley_desktop num visits 36 426
# title_my_library num visits 31 427
# title_cancer_discovery-2013-pemovska-1416-29-1.pdf num visits 2 428
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 3 429
# title_t-61_5010_lecture6_human_perception_part3.pdf num visits 1 430
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 4 431
# title_sacha_knowledge_insight_hypothesis_2014_visualization..._-_google_scholar num visits 2 432
# title_ribarsky_fisher_knowledge_insight_hypothesis_2016..._-_google_scholar num visits 0 433
# title_ieee_xplore_full-text_pdf: num visits 13 434
# title_[1606.03510]_defining_and_conceptualizing_actionable_insight:_a_conceptual_framework_for_decision-centric_analytics num visits 0 435
# title_https://arxiv.org/pdf/1606.03510.pdf num visits 0 436
# title_1606.03510.pdf num visits 0 437
# title_ieee_xplore_full-text_pdf: num visits 14 438
# title_my_library num visits 32 439
# title_ieee_xplore_full-text_pdf: num visits 15 440
# title_juliana_freire,_ph.d._|_nyu_tandon_school_of_engineering num visits 3 441
# title_conceptual_and_methodological_issues_in_evaluating_multidimensional_visualizations_for_decision_support num visits 5 442
# title_hcc_human_interaction_-_google_search num visits 0 443
# title_hcc_human_interaction_-_google_scholar num visits 0 444
# title_human-centred_computing_section_(hcc)_–_university_of_copenhagen num visits 0 445
# title_jørgen_p._bansler_-_ansatte num visits 0 446
# title_jørgen_p._bansler_-_google_search num visits 0 447
# title_jørgen_p._bansler_-_google_scholar_citations num visits 0 448
# title_email_participants_-_google_docs num visits 54 449
# title_dlzi3rgwsaae0o9.jpg-large-1.jpg num visits 5 450
# title_managed_software_centre num visits 6 451
# title_ver7anno_—_node_bin/www_—_80×24 num visits 31 452
# title_my_library num visits 33 453
# title_supporting_communication num visits 2 454
# title_explates: num visits 2 455
# title_supporting_the_analytical_reasoning num visits 7 456
# title_interactive num visits 1 457
# title_individualized_systems_me... num visits 0 458
# title_ver7anno_—_node_bin/www_—_80×24 num visits 32 459
# title_nav_between_folders num visits 1 460
# title_mendeley_desktop num visits 37 461
# title_my_library,knowledge_generation_mo num visits 0 462
# title_insight_provenance_for_vast_view num visits 14 463
# title_wake_up_to_wisdom_view num visits 8 464
# title_implicit_interaction_with_textual_information_using_physiological_signals num visits 1 465
# title_export_to_refworks_-_which_version? num visits 0 466
# title_implicit_interaction_with_textual_information_using_physiological_signals num visits 2 467
# title_export_to_refworks_-_which_version? num visits 1 468
# title_managed_software_centre num visits 7 469
# title_oswald_barral_defends_his_phd_thesis_view num visits 7 470
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 99 471
# title_the_human-computer_sys... num visits 0 472
# title_defining_and_concept_ualizi num visits 0 473
# title_oswald_barral_defends_his_phd_thesis_view num visits 8 474
# title_defining_and_concept_ualizi num visits 1 475
# title_oswald_barral_defends_his_phd_thesis_view num visits 9 476
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 100 477
# title_google_doodles num visits 2 478
# title_new_tab num visits 54 479
# title_vuoden_2018_talviolympialaiset_-_google-haku num visits 1 480
# title_vuoden_2018_talviolympialaisten_mitalitaulukko_–_wikipedia num visits 0 481
# title_2018_winter_olympics_medal_table_-_wikipedia num visits 0 482
# title_creating_a_page_for_kazakhstan_winter_olympics_2018_-_wikipedia num visits 0 483
# title_2018_winter_olympics_medal_table_-_wikipedia num visits 1 484
# title_kazakhstan_-_google_search num visits 0 485
# title_defining_and_concept_ualizi num visits 2 486
# title_oswald_barral_defends_his_phd_thesis_view num visits 10 487
# title_defining_and_concept_ualizi num visits 3 488
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 101 489
# title_luana.micallef_chat num visits 72 490
# title_inbox_view num visits 39 491
# title_oswald_barral_defends_his_phd_thesis_view num visits 11 492
# title_luana.micallef_chat num visits 73 493
# title_web.pdf num visits 4 494
# title_defining_and_concept_ualizi num visits 4 495
# title_luana.micallef_chat num visits 74 496
# title_defining_and_concept_ualizi num visits 5 497
# title_insight_provenance_for_vast_view num visits 15 498
# title_idv_course_structure_view num visits 2 499
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 102 500
# title_defining_and_concept_ualizi num visits 6 501
# title_oswald_barral_defends_his_phd_thesis_view num visits 12 502
# title_defining_and_concept_ualizi num visits 7 503
# title_unisport num visits 8 504
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 103 505
# title_defining_and_concept_ualizi num visits 8 506
# title_defining_and_conceptualizing_actionable_insight:_a_conceptual_framework_for_decision-centric_analytics_-_google_search num visits 0 507
# title_defining_and_conceptualizing_actionable_insight:..._-_google_scholar num visits 0 508
# title_the_human-computer_sys... num visits 1 509
# title_mendeley_desktop num visits 38 510
# title_vairoma:_a_visual_analytics_system_for_making_sense_of_places,_times,_and_events_in_roman_history_-_google_search num visits 0 511
# title_vairoma:_a_visual_analytics_system_for_making_sense_of_places,_times,_and_events_in_roman_history._-_pubmed_-_ncbi num visits 0 512
# title_ieee_xplore_full-text_pdf: num visits 16 513
# title_mendeley_desktop num visits 39 514
# title_the_human-computer_sys... num visits 2 515
# title_knowledge_generation_mo num visits 0 516
# title_the_human-computer_sys... num visits 3 517
# title_knowledge_generation_mo num visits 1 518
# title_mendeley_desktop num visits 40 519
# title_new_tab num visits 55 520
# title_luana.micallef_chat num visits 75 521
# title_publications_|_centre_for_visual_analytics_science_and_technology num visits 3 522
# title_publik_262100.pdf num visits 0 523
# title_ieee_xplore_full-text_pdf: num visits 17 524
# title_myprez num visits 7 525
# title_paper num visits 3 526
# title_01634309.pdf num visits 0 527
# title_paper num visits 4 528
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 0 529
# title_mendeley_desktop num visits 41 530
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 1 531
# title_mendeley_desktop num visits 42 532
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 2 533
# title_mendeley_desktop num visits 43 534
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 3 535
# title_mendeley_desktop num visits 44 536
# title_my_library num visits 34 537
# title_ieee_xplore_full-text_pdf: num visits 18 538
# title_my_library num visits 35 539
# title_mendeley_desktop num visits 45 540
# title_knowledge_generation_mo num visits 2 541
# title_oswald_barral_defends_his_phd_thesis_view num visits 13 542
# title_luana.micallef_chat num visits 76 543
# title_tung_vuong_chat num visits 26 544
# title_popular_sites_in_finland_–_accessible_using_hola num visits 0 545
# title_how_progressive_visualizations_affect_exploratory_analysis_-_google_search num visits 0 546
# title_how_progressive_visualizations_affect_exploratory_analysis_-_ieee_journals_&_magazine num visits 0 547
# title_luana.micallef_chat num visits 77 548
# title_ieee_xplore_full-text_pdf: num visits 19 549
# title_views_on_visualization_-_google_search num visits 0 550
# title_ieee_xplore_full-text_pdf: num visits 20 551
# title_nav_between_folders num visits 2 552
# title_title num visits 10 553
# title_ui.js num visits 8 554
# title_anno.js num visits 30 555
# title_index.html num visits 22 556
# title_new_tab num visits 56 557
# title_medisyn_|_prototype num visits 279 558
# title_index.html num visits 23 559
# title_anno.js num visits 31 560
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 104 561
# title_anno.js num visits 32 562
# title_medisyn_|_prototype num visits 280 563
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 105 564
# title_anno.js num visits 33 565
# title_userauthen.js num visits 58 566
# title_ui.js num visits 9 567
# title_userauthen.js num visits 59 568
# title_medisyn_|_prototype num visits 281 569
# title_knowledge_generation_mo num visits 3 570
# title_ui.js num visits 10 571
# title_medisyn_|_prototype num visits 282 572
# title_web.pdf num visits 5 573
# title_anno.js num visits 34 574
# title_medisyn_|_prototype num visits 283 575
# title_anno.js num visits 35 576
# title_medisyn_|_prototype num visits 284 577
# title_anno.js num visits 36 578
# title_medisyn_|_prototype num visits 285 579
# title_anno.js num visits 37 580
# title_ui.js num visits 11 581
# title_userauthen.js num visits 60 582
# title_dataparser.js num visits 0 583
# title_ui.js num visits 12 584
# title_medisyn_|_prototype num visits 286 585
# title_ui.js num visits 13 586
# title_medisyn_|_prototype num visits 287 587
# title_ui.js num visits 14 588
# title_medisyn_|_prototype num visits 288 589
# title_dataparser.js num visits 1 590
# title_userauthen.js num visits 61 591
# title_ui.js num visits 15 592
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 106 593
# title_medisyn_|_prototype num visits 289 594
# title_index.html num visits 24 595
# title_dataparser.js num visits 2 596
# title_medisyn_|_prototype num visits 290 597
# title_ui.js num visits 16 598
# title_userauthen.js num visits 62 599
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 107 600
# title_medisyn_|_prototype num visits 291 601
# title_userauthen.js num visits 63 602
# title_knowledge_generation_mo num visits 4 603
# title_medisyn_|_prototype num visits 292 604
# title_userauthen.js num visits 64 605
# title_ui.js num visits 17 606
# title_userauthen.js num visits 65 607
# title_ui.js num visits 18 608
# title_svgheader.js num visits 14 609
# title_medisyn_|_prototype num visits 293 610
# title_ui.js num visits 19 611
# title_web.pdf num visits 6 612
# title_medisyn_|_prototype num visits 294 613
# title_ui.js num visits 20 614
# title_how_to_destroy_a_javascript_object?_-_stack_overflow num visits 0 615
# title_medisyn_|_prototype num visits 295 616
# title_ui.js num visits 21 617
# title_web.pdf num visits 7 618
# title_ui.js num visits 22 619
# title_index.html num visits 25 620
# title_ui.js num visits 23 621
# title_knowledge_generation_mo num visits 5 622
# title_medisyn_|_prototype num visits 296 623
# title_web.pdf num visits 8 624
# title_index.html num visits 26 625
# title_ui.js num visits 24 626
# title_index.html num visits 27 627
# title_userauthen.js num visits 66 628
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 108 629
# title_medisyn_|_prototype num visits 297 630
# title_ui.js num visits 25 631
# title_medisyn_|_prototype num visits 298 632
# title_ui.js num visits 26 633
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 109 634
# title_ui.js num visits 27 635
# title_medisyn_|_prototype num visits 299 636
# title_index.html num visits 28 637
# title_userauthen.js num visits 67 638
# title_web.pdf num visits 9 639
# title_userauthen.js num visits 68 640
# title_svgheader.js num visits 15 641
# title_ui.js num visits 28 642
# title_knowledge_generation_mo num visits 6 643
# title_medisyn_|_prototype num visits 300 644
# title_knowledge_generation_mo num visits 7 645
# title_ui.js num visits 29 646
# title_medisyn_|_prototype num visits 301 647
# title_ui.js num visits 30 648
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 110 649
# title_medisyn_|_prototype num visits 302 650
# title_elements.css num visits 34 651
# title_main.css num visits 0 652
# title_ui.js num visits 31 653
# title_medisyn_|_prototype num visits 303 654
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 111 655
# title_inbox_view num visits 40 656
# title_medisyn_|_prototype num visits 304 657
# title_javascript_destroy_object_-_google_search num visits 0 658
# title_inbox_view num visits 41 659
# title_insight_provenance_for_vast_view num visits 16 660
# title_luana.micallef_chat num visits 78 661
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 112 662
# title_history_evaluation num visits 63 663
# title_luana.micallef_chat num visits 79 664
# title_insight_provenance_for_vast_view num visits 17 665
# title_medisyn_questionnaire_-_google_forms num visits 60 666
# title_luana.micallef_chat num visits 80 667
# title_interactive_recommender_systems:_a_survey_of_the_state_of_the_art_and_future_research_challenges_and_opportunities num visits 0 668
# title_medisyn_questionnaire_-_google_forms num visits 61 669
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 4 670
# title_history_evaluation num visits 64 671
# title_how_to_destroy_a_javascript_object?_-_stack_overflow num visits 1 672
# title_luana.micallef_chat num visits 81 673
# title_how_to_destroy_a_javascript_object?_-_stack_overflow num visits 2 674
# title_the_role_of_explicit_knowledge:_a_conceptual_model_of_knowledge-assisted_visual_analytics num visits 5 675
# title_how_progressive_visualizations_affect_exploratory_analysis_-_google_search num visits 1 676
# title_luana.micallef_chat num visits 82 677
# title_medisyn_questionnaire_-_google_forms num visits 62 678
# title_luana.micallef_chat num visits 83 679
# title_medisyn_questionnaire_-_google_forms num visits 63 680
# title_luana.micallef_chat num visits 84 681
# title_medisyn_questionnaire_-_google_forms num visits 64 682
# title_ieee_xplore_full-text_pdf: num visits 21 683
# title_luana.micallef_chat num visits 85 684
# title_history_evaluation num visits 65 685
# title_vairoma:_a_visual_analytics_system_for_making_sense_of_places,_times,_and_events_in_roman_history._-_pubmed_-_ncbi num visits 1 686
# title_javascript_destroy_object_-_google_search num visits 1 687
# title_https://d4health.hiit.fi/alluserhis num visits 12 688
# title_https://d4health.hiit.fi/retrieveallhis num visits 62 689
# title_insight_provenance_for_vast_view num visits 18 690
# title_email_participants_-_google_docs num visits 55 691
# title_medisyn_|_prototype num visits 305 692
# title_https://d4health.hiit.fi/alluserhis num visits 13 693
# title_https://d4health.hiit.fi/retrieveallhis num visits 63 694
# title_history_evaluation num visits 66 695
# title_ui.js num visits 32 696
# title_userauthen.js num visits 69 697
# title_history_evaluation num visits 67 698
# title_medisyn_|_prototype num visits 306 699
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 113 700
# title_userauthen.js num visits 70 701
# title_history_evaluation num visits 68 702
# title_https://d4health.hiit.fi/retrieveallhis num visits 64 703
# title_ieee_xplore_full-text_pdf: num visits 22 704
# title_medisyn_|_prototype num visits 307 705
# title_https://d4health.hiit.fi/retrieveallhis num visits 65 706
# title_medisyn_|_prototype num visits 308 707
# title_email_participants_-_google_docs num visits 56 708
# title_medisyn_|_prototype num visits 309 709
# title_https://d4health.hiit.fi/retrieveallhis num visits 66 710
# title_medisyn_|_prototype num visits 310 711
# title_https://d4health.hiit.fi/retrieveallhis num visits 67 712
# title_medisyn_|_prototype num visits 311 713
# title_https://d4health.hiit.fi/retrieveallhis num visits 68 714
# title_https://d4health.hiit.fi/alluserhis num visits 14 715
# title_medisyn_|_prototype num visits 312 716
# title_https://d4health.hiit.fi/retrieveallhis num visits 69 717
# title_medisyn_|_prototype num visits 313 718
# title_https://d4health.hiit.fi/retrieveallhis num visits 70 719
# title_medisyn_|_prototype num visits 314 720
# title_https://d4health.hiit.fi/retrieveallhis num visits 71 721
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 114 722
# title_medisyn_|_prototype num visits 315 723
# title_https://d4health.hiit.fi/retrieveallhis num visits 72 724
# title_medisyn_|_prototype num visits 316 725
# title_medisyn_|_history num visits 165 726
# title_https://d4health.hiit.fi/retrieveallhis num visits 73 727
# title_medisyn_|_prototype num visits 317 728
# title_medisyn_|_history num visits 166 729
# title_email_participants_-_google_docs num visits 57 730
# title_medisyn_questionnaire_-_google_forms num visits 65 731
# title_medisyn_|_history num visits 167 732
# title_https://d4health.hiit.fi/retrieveallhis num visits 74 733
# title_medisyn_|_prototype num visits 318 734
# title_medisyn_|_history num visits 168 735
# title_medisyn_|_prototype num visits 319 736
# title_medisyn_|_history num visits 169 737
# title_medisyn_|_prototype num visits 320 738
# title_medisyn_|_history num visits 170 739
# title_userauthen.js num visits 71 740
# title_history.js num visits 27 741
# title_web.pdf num visits 10 742
# title_history.js num visits 28 743
# title_history.html num visits 9 744
# title_history.js num visits 29 745
# title_drawhistory.js num visits 39 746
# title_index.html num visits 29 747
# title_userauthen.js num visits 72 748
# title_medisyn_|_history num visits 171 749
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 115 750
# title_ui.js num visits 33 751
# title_drawhistory.js num visits 40 752
# title_history.js num visits 30 753
# title_drawhistory.js num visits 41 754
# title_history.html num visits 10 755
# title_history.js num visits 31 756
# title_drawhistory.js num visits 42 757
# title_history.js num visits 32 758
# title_main.css num visits 1 759
# title_history.html num visits 11 760
# title_userauthen.js num visits 73 761
# title_drawhistory.js num visits 43 762
# title_history.html num visits 12 763
# title_jquery_select_menu_-_google_search num visits 0 764
# title_javascript_select_menu_-_google_search num visits 0 765
# title_jquery_-_javascript_select_menu_with_javascript_-_stack_overflow num visits 0 766
# title_javascript_select_menu_set_initial_-_google_search num visits 0 767
# title_html_-_how_do_i_programmatically_set_the_value_of_a_select_box_element_using_javascript?_-_stack_overflow num visits 0 768
# title_history.html num visits 13 769
# title_javascript_-_html5_localstorage:_checking_if_a_key_exists_-_stack_overflow num visits 0 770
# title_history.html num visits 14 771
# title_managed_software_centre num visits 8 772
# title_new_tab num visits 57 773
# title_medisyn_|_prototype num visits 321 774
# title_medisyn_|_history num visits 172 775
# title_history.html num visits 15 776
# title_javascript_selectmenu_set_initial_-_google_search num visits 0 777
# title_web.pdf num visits 11 778
# title_medisyn_|_history num visits 173 779
# title_web.pdf num visits 12 780
# title_history.html num visits 16 781
# title_web.pdf num visits 13 782
# title_medisyn_|_history num visits 174 783
# title_medisyn_|_prototype num visits 322 784
# title_history.html num visits 17 785
# title_web.pdf num visits 14 786
# title_history.html num visits 18 787
# title_medisyn_|_history num visits 175 788
# title_web.pdf num visits 15 789
# title_history.html num visits 19 790
# title_medisyn_|_prototype num visits 323 791
# title_medisyn_|_history num visits 176 792
# title_drawhistory.js num visits 44 793
# title_medisyn_|_history num visits 177 794
# title_history.html num visits 20 795
# title_web.pdf num visits 16 796
# title_medisyn_|_prototype num visits 324 797
# title_medisyn_|_history num visits 178 798
# title_history.js num visits 33 799
# title_history.html num visits 21 800
# title_history.js num visits 34 801
# title_history_evaluation num visits 69 802
# title_medisyn_|_prototype num visits 325 803
# title_history_evaluation num visits 70 804
# title_history.js num visits 35 805
# title_drawhistory.js num visits 45 806
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 116 807
# title_medisyn_|_history num visits 179 808
# title_web.pdf num visits 17 809
# title_userauthen.js num visits 74 810
# title_history.js num visits 36 811
# title_sessionstorage_across_three_windows_-_google_search num visits 0 812
# title_session_variables_-_javascript_sessionstorage_across_tabs?_-_stack_overflow num visits 0 813
# title_history.js num visits 37 814
# title_history.html num visits 22 815
# title_drawhistory.js num visits 46 816
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 117 817
# title_medisyn_|_prototype num visits 326 818
# title_medisyn_|_history num visits 180 819
# title_medisyn_|_prototype num visits 327 820
# title_medisyn_|_history num visits 181 821
# title_web.pdf num visits 18 822
# title_drawhistory.js num visits 47 823
# title_history.js num visits 38 824
# title_history.html num visits 23 825
# title_find_results num visits 0 826
# title_history.js num visits 39 827
# title_history.html num visits 24 828
# title_find_results num visits 1 829
# title_history.js num visits 40 830
# title_history.html num visits 25 831
# title_medisyn_|_prototype num visits 328 832
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 118 833
# title_web.pdf num visits 19 834
# title_history.html num visits 26 835
# title_history_evaluation num visits 71 836
# title_oswald_barral_defends_his_phd_thesis_view num visits 14 837
# title_your_application_in_enter_finland_is_waiting_to_be_processed_view num visits 0 838
# title_web.pdf num visits 20 839
# title_history_evaluation num visits 72 840
# title_medisyn_|_history num visits 182 841
# title_history_evaluation num visits 73 842
# title_https://d4health.hiit.fi/retrieveallhis num visits 75 843
# title_medisyn_|_prototype num visits 329 844
# title_slack_-_ubiquitous_interaction_(uix)_group num visits 11 845
# title_medisyn_|_prototype num visits 330 846
# title_ver7anno_—_node_bin/www_—_80×24 num visits 33 847
# title_ver4mongodb_—_mongod_◂_sudo_—_80×24 num visits 10 848
# title_chenhe_—_-bash_—_80×24 num visits 11 849
# title_chenhe_—_ssh_-d8080_shell.hiit.fi_—_80×24 num visits 6 850
# title_chenhe_—_chenhe@shell:_~_—_ssh_-d8080_shell.hiit.fi_—_80×24 num visits 12 851
# title_filezilla num visits 9 852
# title_paper num visits 5 853
# title_prototypes num visits 3 854
# title_ver7anno num visits 4 855
# title_new_site_-_sftp://chenhe@shoulder.hiit.fi_-_filezilla num visits 56 856
# title_https://d4health.hiit.fi/retrieveallhis num visits 76 857
# title_history_evaluation num visits 74 858
# title_history.html num visits 27 859
# title_allhis.html num visits 8 860
# title_drawallhistory.js num visits 27 861
# title_lidwell,_holden,_butler_-_2010_-_universal_principles_of_design.pdf num visits 119 862
# title_localhost:3000/retrieveallhis num visits 19 863
# title_web.pdf num visits 21 864
# title_drawallhistory.js num visits 28 865
# title_localhost:3000/retrieveallhis num visits 20 866
# title_drawallhistory.js num visits 29 867
# title_localhost:3000/retrieveallhis num visits 21 868
# title_new_site_-_sftp://chenhe@shoulder.hiit.fi_-_filezilla num visits 57 869
# title_https://d4health.hiit.fi/retrieveallhis num visits 77 870
# title_new_site_-_sftp://chenhe@shoulder.hiit.fi_-_filezilla num visits 58 871
# title_https://d4health.hiit.fi/retrieveallhis num visits 78 872
# title_luana.micallef_chat num visits 86 873
# title_https://d4health.hiit.fi/retrieveallhis num visits 79 874
# title_luana.micallef_chat num visits 87 875
# title_https://d4health.hiit.fi/retrieveallhis num visits 80 876
# title_medisyn_|_prototype num visits 331 877
# title_https://d4health.hiit.fi/retrieveallhis num visits 81 878
# title_luana.micallef_chat num visits 88 879
# title_https://d4health.hiit.fi/retrieveallhis num visits 82 880
# title_luana.micallef_call num visits 8 881
# title_https://d4health.hiit.fi/retrieveallhis num visits 83 882
# title_inbox_view num visits 42 883
# title_your_application_in_enter_finland_is_waiting_to_be_processed_view num visits 1 884
# title_insight_provenance_for_vast_view num visits 19 885
# title_email_participants_-_google_docs num visits 58 886
# title_luana.micallef_call num visits 9 887
# title_email_participants_-_google_docs num visits 59 888
# title_luana_micallef_-_google_search num visits 0 889
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 0 890
# title_scatterplot_design_optimization num visits 0 891
# title_luana.micallef_call num visits 10 892
# title_scatterplot_design_optimization num visits 1 893
# title_invitation_to_the_int'l_congress_view num visits 0 894
# title_insight_provenance_for_vast_view num visits 20 895
# title_luana.micallef_call num visits 11 896
# title_your_application_in_enter_finland_is_waiting_to_be_processed_view num visits 2 897
# title_luana.micallef_call num visits 12 898
# title_scientific_study_on_scatterplots num visits 0 899
# title_examples_of_online_studies_view num visits 0 900
# title_scientific_study_on_scatterplots num visits 1 901
# title_scatterplot_design_optimization num visits 2 902
# title_luana.micallef_chat num visits 89 903
# title_examples_of_online_studies_view num visits 1 904
# title_apologies_for_spurious_messages_view num visits 0 905
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 70 906
# title_luana.micallef_chat num visits 90 907
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 71 908
# title_luana.micallef_call num visits 13 909
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 72 910
# title_scatterplot_design_optimization num visits 3 911
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 1 912
# title_scatterplot_design_optimization num visits 4 913
# title_scientific_study_on_scatterplots num visits 2 914
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 73 915
# title_luana_micallef_-_google_search num visits 1 916
# title_medisyn_|_prototype num visits 332 917
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 2 918
# title_scatterplot_design_optimization num visits 5 919
# title_scientific_study_on_scatterplots num visits 3 920
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 3 921
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 74 922
# title_examples_of_online_studies_view num visits 2 923
# title_luana.micallef_call num visits 14 924
# title_examples_of_online_studies_view num visits 3 925
# title_luana.micallef_call num visits 15 926
# title_examples_of_online_studies_view num visits 4 927
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 4 928
# title_examples_of_online_studies_view num visits 5 929
# title_scientific_study_on_scatterplots num visits 4 930
# title_luana.micallef_call num visits 16 931
# title_scientific_study_on_scatterplots num visits 5 932
# title_luana.micallef_call num visits 17 933
# title_scientific_study_on_scatterplots num visits 6 934
# title_wake_up_to_wisdom_view num visits 9 935
# title_examples_of_online_studies_view num visits 6 936
# title_scientific_study_on_scatterplots num visits 7 937
# title_luana.micallef_call num visits 18 938
# title_luana.micallef_chat num visits 91 939
# title_scientific_study_on_scatterplots num visits 8 940
# title_luana.micallef_chat num visits 92 941
# title_scientific_study_on_scatterplots num visits 9 942
# title_luana.micallef_chat num visits 93 943
# title_scientific_study_on_scatterplots num visits 10 944
# title_luana.micallef_chat num visits 94 945
# title_scientific_study_on_scatterplots num visits 11 946
# title_luana.micallef_chat num visits 95 947
# title_scientific_study_on_scatterplots num visits 12 948
# title_luana.micallef_chat num visits 96 949
# title_scientific_study_on_scatterplots num visits 13 950
# title_scatterplot_design_optimization num visits 6 951
# title_luana.micallef_chat num visits 97 952
# title_inbox_view num visits 43 953
# title_scientific_study_on_scatterplots num visits 14 954
# title_https://www.cs.kent.ac.uk/people/staff/lm357/crowdflower/scatteropt_tvcg2017/fortesting/clu/saveanswers.php num visits 0 955
# title_scatterplot_design_optimization num visits 7 956
# title_new_tab num visits 58 957
# title_google_forms_-_google_search num visits 4 958
# title_google_forms num visits 19 959
# title_examples_of_online_studies_view num visits 7 960
# title_book_allpages.pdf num visits 0 961
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 75 962
# title_medisyn_|_prototype num visits 333 963
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 76 964
# title_online_user_study_with_movie_tickets_as_rewards_compose num visits 31 965
# title_examples_of_online_studies_view num visits 8 966
# title_medisyn_|_prototype num visits 334 967
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 77 968
# title_examples_of_online_studies_view num visits 9 969
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 5 970
# title_luana.micallef_chat num visits 98 971
# title_luana_micallef_|_postdoctoral_researcher_|_luana.micallef@hiit.fi num visits 6 972
# title_home_page_for_l_micallef_-_school_of_computing_-_university_of_kent num visits 0 973
# title_luana.micallef_call num visits 19 974
# title_home_page_for_l_micallef_-_school_of_computing_-_university_of_kent num visits 1 975
# title_luana.micallef_call num visits 20 976
# title_all_notes num visits 107 977
# title_medisyn_|_prototype num visits 335 978
# title_home_page_for_l_micallef_-_school_of_computing_-_university_of_kent num visits 2 979
# title_medisyn_|_prototype num visits 336 980
# title_new_tab num visits 59 981
# title_medisyn_|_prototype num visits 337 982
# title_medisyn_|_history num visits 183 983
# title_medisyn_|_prototype num visits 338 984
# title_luana.micallef_call num visits 21 985
# title_medisyn_|_prototype num visits 339 986
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 78 987
# title_calendar num visits 20 988
# title_online_user_study_with_movie_tickets_as_rewards_view num visits 79 989
# title_invitation_to_design_critique_view num visits 0 990
# title_invitation_to_design_critique_compose num visits 0 991
# title_invitation_to_design_critique_view num visits 1 992
# title_examples_of_online_studies_view num visits 10 993
# title_invitation_to_design_critique_view num visits 2 994
# title_new_message_compose num visits 23 995
# title_insight_provenance_for_vast_view num visits 21 996
# title_insight_provenance_for_vast_compose num visits 24 997
# title_history_evaluation num visits 75 998
# **Makov
# Hitrate@1:  0.15756035578144853
# Hitrate@2:  0.22236340533672172
# Hitrate@3:  0.2770012706480305
# Hitrate@4:  0.3138500635324015
# Hitrate@5:  0.3519695044472681
# MRR:  0.24561476023956982
# **Frequency recency
# Hitrate@1:  0.24015247776365947
# Hitrate@2:  0.3405336721728081
# Hitrate@3:  0.397712833545108
# Hitrate@4:  0.4256670902160102
# Hitrate@5:  0.45616264294790343
# MRR:  0.3343551555599338
# **Access rank
# Hitrate@1:  0.2554002541296061
# Hitrate@2:  0.40025412960609913
# Hitrate@3:  0.47903430749682335
# Hitrate@4:  0.5298602287166455
# Hitrate@5:  0.5705209656925032
# MRR:  0.401246859485111
# **Routine
# Hitrate@1:  0.10165184243964422
# Hitrate@2:  0.14104193138500634
# Hitrate@3:  0.1905972045743329
# Hitrate@4:  0.22744599745870395
# Hitrate@5:  0.25412960609911056
# MRR:  0.1852380864342718
